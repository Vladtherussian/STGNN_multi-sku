# %%
import pandas as pd
from pathlib import Path

# 1. Setup paths (adjust to your project root)
PROJECT_ROOT = Path(r"C:\Users\Vladi\OneDrive\Documents\STGNN_multi-sku")
DATA_PATH = PROJECT_ROOT / "data" / "processed" / "ml_ready_data.parquet"

# 2. Load the data
df = pd.read_parquet(DATA_PATH)

# 3. Recreate the exact index mapping used in the training pipeline
# We must sort by unique_id to match the tensor preparation logic
nodes_metadata = df[['unique_id', 'item_id', 'dept_id', 'store_id']].drop_duplicates().sort_values("unique_id")

# 4. Create a lookup function
def lookup_node(node_index):
    row = nodes_metadata.iloc[node_index]
    return {
        "unique_id": row['unique_id'],
        "item_id": row['item_id'],
        "dept_id": row['dept_id'],
        "store_id": row['store_id']
    }

# Example: Look up Node 0 and Node 144
print(f"Node 0: {lookup_node(0)}")
print(f"Node 584: {lookup_node(584)}")
# Out:
# Node 0: {'unique_id': 'FOODS_1_004_CA_1_evaluation', 'item_id': np.int64(0), 'dept_id': np.int64(0), 'store_id': np.int64(0)}
# Node 584: {'unique_id': 'FOODS_3_574_TX_3_evaluation', 'item_id': np.int64(140), 'dept_id': np.int64(2), 'store_id': np.int64(6)}

# %%
details
# Out:
# {'unique_id': 'FOODS_3_458_TX_3_evaluation',
#  'item_id': np.int64(117),
#  'dept_id': np.int64(2),
#  'store_id': np.int64(6)}

# %%
# Assuming 'indices' is the list from your console [0, 144, 21, 186, 45]
top_5_indices = [0, 584, 646, 320, 474]
for idx in top_5_indices:
    details = lookup_node(idx)
    print(f"Node {idx}: {details['item_id']} in Store: {details['store_id']} in Department: {details['dept_id']}")
# Out:
# Node 0: 0 in Store: 0 in Department: 0
# Node 584: 140 in Store: 6 in Department: 2
# Node 646: 151 in Store: 5 in Department: 2
# Node 320: 83 in Store: 2 in Department: 2
# Node 474: 117 in Store: 6 in Department: 2

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 74
#      70
#      71 if __name__ == "__main__":
#      72     # You can change this string to any specific item ID from your logs
#      73     # (e.g., 'FOODS_1_004_CA_1') to investigate exactly how it behaved.
# ---> 74     plot_forecast()
#
# Cell In[9], line 69, in plot_forecast(target_item)
#      65             trace.line.width = 1.5
#      66             trace.visible = 'legendonly' # Hide the other baselines by default to reduce clutter
#      67
#      68     # 5. Launch in the Browser!
# ---> 69     fig.show()
#
# File c:\Users\Vladi\OneDrive\Documents\STGNN_multi-sku\.venv\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File c:\Users\Vladi\OneDrive\Documents\STGNN_multi-sku\.venv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
